# %% [markdown]
# # Facial Emotion Recogination

# %% [markdown]
# ## importing libraries

# %%
# Importing the required libraries for creating a model and testing it

# Used for working with arrays
import numpy as np  

# It is used for data manipulation and analysis
import pandas as pd 

# Stands for Operating System used to work with the operating system
import os   

# It is for fast computation of data
import tensorflow as tf 

 # Used to process Images
from keras.preprocessing.image import ImageDataGenerator, load_img 

# Used for computation of data
from keras.layers import Conv2D, Dense, BatchNormalization, Activation, Dropout, MaxPooling2D, Flatten  

# To Optimize the model
from tensorflow.keras.optimizers import Adam, RMSprop, SGD  

# Working with model 
from keras import regularizers  

# Importing modules to work with the model
from keras.callbacks import ModelCheckpoint, CSVLogger, TensorBoard, EarlyStopping, ReduceLROnPlateau

# Working with date and time
import datetime  

# Used for visualization of data
import matplotlib.pyplot as plt   

# For ploting a model
from tensorflow.keras.utils import plot_model

# %% [markdown]
# ## Importing Dataset

# %%
# The directories of the training dataset and testing dataset
train_dir = './Dataset/train/'  
test_dir = './Dataset/test/'

# Specifying the size of images as 48 x 48
row, col = 48, 48

# There are 7 types of emotions in the dataset
classes = 7 

# Counting the total number of images in each class
def count_exp(path, set_):
    dict_ = {}
    for expression in os.listdir(path):
        dir_ = path + expression
        dict_[expression] = len(os.listdir(dir_))
    df = pd.DataFrame(dict_, index=[set_])
    return df
  
# Storing them in a variable and printing it to console
train_count = count_exp(train_dir, 'train')
test_count = count_exp(test_dir, 'test')
print(train_count)
print(test_count)
# Out:
#        angry  disgust  fear  happy  neutral   sad  surprise
# train   3995      436  4097   7215     4965  4830      3171
#       angry  disgust  fear  happy  neutral   sad  surprise
# test    958      111  1024   1774     1233  1247       831

# %% [markdown]
# ### PLot of number of images in training set

# %%
# Ploting the training data count of each emotion as bar graph
train_count.transpose().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### PLot of number of images in test set

# %%
test_count.transpose().plot(kind='bar')  # Ploting the testing data count of each emotion.
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(14,22))
i = 1
# Printing some of the images from each class
for expression in os.listdir(train_dir):
    img = load_img((train_dir + expression +'/'+ os.listdir(train_dir + expression)[5]))  # Loading the image
    plt.subplot(1,7,i)  # Plotting it to the plot at ith position
    plt.imshow(img)     # Show the image in the plot
    plt.title(expression) # Providing a title for the plot
    plt.axis('off')
    i += 1
plt.show()  # Displaying the plot

# %% [markdown]
# ## Creating Training and test sets

# %% [markdown]
# #### The characteristics defined for training and testing model are :
#
# *   rescale : It is rescaling factor, defaults to None. If None or 0, no rescaling is applied, otherwise we multiply the data by the value provided
# *   zoom_range : It's a float value or [lower, upper]
# *   horizontal_flip : Boolean. Randomly flip inputs horizontally.
# *   batch_size: the batch size (1 <= batch_size <= training dataset size), defaults to 32.
# *   shuffle : Whether to shuffle the data, defaults to True.
# *   color_mode : Allowed values are "grayscale", "rgb", "rgba".

# %%
# Extracts the data from the training images by horizontally flipping them
train_datagen = ImageDataGenerator(rescale=1./255,
                                   zoom_range=0.3,
                                   horizontal_flip=True)

# Getting the training set from the training images directory with color mode as grayscale
training_set = train_datagen.flow_from_directory(train_dir,
                                                batch_size=64,
                                                target_size=(48,48),
                                                shuffle=True,
                                                color_mode='grayscale',
                                                class_mode='categorical')

# Extracts the data from the testing images by horizontally flipping them
test_datagen = ImageDataGenerator(rescale=1./255)

# Getting the testing set from the testing images directory with color mode as grayscale
test_set = test_datagen.flow_from_directory(test_dir,
                                                batch_size=64,
                                                target_size=(48,48),
                                                shuffle=True,
                                                color_mode='grayscale',
                                                class_mode='categorical')
# Out:
# Found 28709 images belonging to 7 classes.
# Found 7178 images belonging to 7 classes.

# %%
# Printing the types of emotions in the given dataset
training_set.class_indices
# Out:
# {'angry': 0,
#  'disgust': 1,
#  'fear': 2,
#  'happy': 3,
#  'neutral': 4,
#  'sad': 5,
#  'surprise': 6}

# %% [markdown]
# ## Defining Model

# %%
# Defining the Model

def get_model(input_size, classes=7):
     #Initialising the CNN
    model = tf.keras.models.Sequential()   

    # creating a Sequential model incrementally via the add() method
    model.add(Conv2D(32, kernel_size=(3, 3), padding='same', activation='relu', input_shape =input_size))  # Creating a convolution kernel producing a tensor of outputs
    model.add(Conv2D(64, kernel_size=(3, 3), activation='relu', padding='same'))
    model.add(BatchNormalization())  # Applies a transformation to data to normalize it
    model.add(MaxPooling2D(2, 2))    # Downsampling the input along its spatial dimensions
    model.add(Dropout(0.25))         # Applying Dropout to the input data
    
    # Applying the rectified linear unit activation 
    model.add(Conv2D(128, kernel_size=(3, 3), activation='relu', padding='same', kernel_regularizer=regularizers.l2(0.01)))
    model.add(Conv2D(256, kernel_size=(3, 3), activation='relu', kernel_regularizer=regularizers.l2(0.01)))
    model.add(BatchNormalization())
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.25))
    

    model.add(Conv2D(512, kernel_size=(3,3), activation='relu', padding='same', kernel_regularizer=regularizers.l2(0.01)))
    model.add(Conv2D(512, kernel_size=(3,3), activation='relu', padding='same', kernel_regularizer=regularizers.l2(0.01)))
    model.add(BatchNormalization())
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.25))
    
    # Flatenning the data
    model.add(Flatten())
    model.add(Dense(1024, activation='relu'))
    model.add(Dropout(0.5))
    
    model.add(Dense(classes, activation='softmax'))

    #Compliling the model
    model.compile(optimizer=Adam(lr=0.0001, decay=1e-6), 
                  loss='categorical_crossentropy', 
                  metrics=['accuracy'])
    # Returning the model
    return model

# %%
# Using the model function created above
fernet = get_model((row,col,1), classes)
fernet.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 48, 48, 32)        320
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 48, 48, 64)        18496
# _________________________________________________________________
# batch_normalization (BatchNo (None, 48, 48, 64)        256
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 24, 24, 64)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 24, 24, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 24, 24, 128)       73856
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 22, 22, 256)       295168
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 22, 22, 256)       1024
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 11, 11, 256)       0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 11, 11, 256)       0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 11, 11, 512)       1180160
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 11, 11, 512)       2359808
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 11, 11, 512)       2048
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 5, 5, 512)         0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 5, 5, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 12800)             0
# _________________________________________________________________
# dense (Dense)                (None, 1024)              13108224
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 7)                 7175
# =================================================================
# Total params: 17,046,535
# Trainable params: 17,044,871
# Non-trainable params: 1,664
# _________________________________________________________________
# C:\Users\Ki\Downloads\AI Project\Human-Emotion-Detection\env\lib\site-packages\keras\optimizer_v2\optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(

# %%
# Plotting all the layers in the model 
plot_model(fernet, to_file='./Images/Layers.png', show_shapes=True, show_layer_names=True)

# %% [markdown]
# ### Callbacks Function

# %%
chk_path = './Model/Model.h5'  # The file name to save the model

# The directory is created by appending the date and time to it for storing the logs
log_dir = "checkpoint/logs/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")

# Callback to save the model weights at some frequency
checkpoint = ModelCheckpoint(filepath=chk_path,
                             save_best_only=True,
                             verbose=1,
                             mode='min',
                             moniter='val_loss')

# Stoping the training when a monitored metric has stopped improving
earlystop = EarlyStopping(monitor='val_loss', 
                          min_delta=0, 
                          patience=3, 
                          verbose=1, 
                          restore_best_weights=True)

# Reducing the learning rate of the model when a metric has stopped improving     
reduce_lr = ReduceLROnPlateau(monitor='val_loss', 
                              factor=0.2, 
                              patience=6, 
                              verbose=1, 
                              min_delta=0.0001)

# Logging the details to the logs in log_dir directory
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1)
csv_logger = CSVLogger('./Logs/training.log')

# Storing all the callbacks in a list for further use
callbacks = [checkpoint, reduce_lr, csv_logger]

# %% [markdown]
# ## Training Model
#
# Options used for training the model :
#
#
# *   x : Input data for the model.
# *   validation_data : Data on which to evaluate the loss and any model metrics at the end of each epoch. The model will not be trained on this data.
# *   epochs: Integer. Number of epochs to train the model. An epoch is an iteration over the entire x and y data provided.
# *   callbacks: List of Callback instances that are needed to apply during training.
# * steps_per_epoch: Total number of steps (batches of samples) before declaring one epoch finished and starting the next epoch.
# * validation_steps : number of steps (batches of samples) to draw before stopping when performing validation at the end of every epoch.

# %%
# Training the model

# Dividing the number of images in training dataset with batch size
# gives us the total number of steps for training dataset

steps_per_epoch = training_set.n // training_set.batch_size

# Dividing the number of images in testing dataset with batch size
# gives us the total number of steps for testing dataset

validation_steps = test_set.n // test_set.batch_size

# Actual training of the model by providing the training dataset,callbacks and testing dataset for validation
hist = fernet.fit(x=training_set,
                 validation_data=test_set,
                 epochs=60,
                 callbacks=callbacks,
                 steps_per_epoch=steps_per_epoch,
                 validation_steps=validation_steps)
# Out:
# Epoch 1/60
# 448/448 [==============================] - ETA: 0s - loss: 12.2310 - accuracy: 0.2616
# Epoch 00001: val_loss improved from inf to 12.11810, saving model to ferNet.h5
# 448/448 [==============================] - 75s 167ms/step - loss: 12.2310 - accuracy: 0.2616 - val_loss: 12.1181 - val_accuracy: 0.2052
# Epoch 2/60
# 448/448 [==============================] - ETA: 0s - loss: 9.6264 - accuracy: 0.3194
# Epoch 00002: val_loss improved from 12.11810 to 8.32903, saving model to ferNet.h5
# 448/448 [==============================] - 34s 76ms/step - loss: 9.6264 - accuracy: 0.3194 - val_loss: 8.3290 - val_accuracy: 0.3958
# Epoch 3/60
# 448/448 [==============================] - ETA: 0s - loss: 7.2760 - accuracy: 0.3626
# Epoch 00003: val_loss improved from 8.32903 to 6.24445, saving model to ferNet.h5
# 448/448 [==============================] - 36s 80ms/step - loss: 7.2760 - accuracy: 0.3626 - val_loss: 6.2445 - val_accuracy: 0.4029
# Epoch 4/60
# 448/448 [==============================] - ETA: 0s - loss: 5.4266 - accuracy: 0.3881
# Epoch 00004: val_loss improved from 6.24445 to 4.55218, saving model to ferNet.h5
# 448/448 [==============================] - 37s 83ms/step - loss: 5.4266 - accuracy: 0.3881 - val_loss: 4.5522 - val_accuracy: 0.4554
# Epoch 5/60
# 448/448 [==============================] - ETA: 0s - loss: 4.0909 - accuracy: 0.4188
# Epoch 00005: val_loss improved from 4.55218 to 3.45955, saving model to ferNet.h5
# 448/448 [==============================] - 35s 77ms/step - loss: 4.0909 - accuracy: 0.4188 - val_loss: 3.4596 - val_accuracy: 0.4809
# Epoch 6/60
# 448/448 [==============================] - ETA: 0s - loss: 3.1617 - accuracy: 0.4543
# Epoch 00006: val_loss improved from 3.45955 to 2.70427, saving model to ferNet.h5
# 448/448 [==============================] - 35s 78ms/step - loss: 3.1617 - accuracy: 0.4543 - val_loss: 2.7043 - val_accuracy: 0.4887
# Epoch 7/60
# 448/448 [==============================] - ETA: 0s - loss: 2.5583 - accuracy: 0.4692
# Epoch 00007: val_loss improved from 2.70427 to 2.24101, saving model to ferNet.h5
# 448/448 [==============================] - 34s 75ms/step - loss: 2.5583 - accuracy: 0.4692 - val_loss: 2.2410 - val_accuracy: 0.5301
# Epoch 8/60
# 448/448 [==============================] - ETA: 0s - loss: 2.1573 - accuracy: 0.4945
# Epoch 00008: val_loss improved from 2.24101 to 1.93760, saving model to ferNet.h5
# 448/448 [==============================] - 34s 77ms/step - loss: 2.1573 - accuracy: 0.4945 - val_loss: 1.9376 - val_accuracy: 0.5350
# Epoch 9/60
# 448/448 [==============================] - ETA: 0s - loss: 1.9077 - accuracy: 0.5081
# Epoch 00009: val_loss improved from 1.93760 to 1.79018, saving model to ferNet.h5
# 448/448 [==============================] - 34s 75ms/step - loss: 1.9077 - accuracy: 0.5081 - val_loss: 1.7902 - val_accuracy: 0.5272
# Epoch 10/60
# 448/448 [==============================] - ETA: 0s - loss: 1.7450 - accuracy: 0.5195
# Epoch 00010: val_loss improved from 1.79018 to 1.62511, saving model to ferNet.h5
# 448/448 [==============================] - 34s 75ms/step - loss: 1.7450 - accuracy: 0.5195 - val_loss: 1.6251 - val_accuracy: 0.5389
# Epoch 11/60
# 448/448 [==============================] - ETA: 0s - loss: 1.6256 - accuracy: 0.5342
# Epoch 00011: val_loss improved from 1.62511 to 1.46879, saving model to ferNet.h5
# 448/448 [==============================] - 34s 76ms/step - loss: 1.6256 - accuracy: 0.5342 - val_loss: 1.4688 - val_accuracy: 0.5749
# Epoch 12/60
# 448/448 [==============================] - ETA: 0s - loss: 1.5330 - accuracy: 0.5456
# Epoch 00012: val_loss improved from 1.46879 to 1.45710, saving model to ferNet.h5
# 448/448 [==============================] - 35s 77ms/step - loss: 1.5330 - accuracy: 0.5456 - val_loss: 1.4571 - val_accuracy: 0.5672
# Epoch 13/60
# 448/448 [==============================] - ETA: 0s - loss: 1.4667 - accuracy: 0.5544
# Epoch 00013: val_loss improved from 1.45710 to 1.41899, saving model to ferNet.h5
# 448/448 [==============================] - 34s 77ms/step - loss: 1.4667 - accuracy: 0.5544 - val_loss: 1.4190 - val_accuracy: 0.5649
# Epoch 14/60
# 448/448 [==============================] - ETA: 0s - loss: 1.4163 - accuracy: 0.5650
# Epoch 00014: val_loss improved from 1.41899 to 1.33933, saving model to ferNet.h5
# 448/448 [==============================] - 34s 76ms/step - loss: 1.4163 - accuracy: 0.5650 - val_loss: 1.3393 - val_accuracy: 0.5878
# Epoch 15/60
# 448/448 [==============================] - ETA: 0s - loss: 1.3706 - accuracy: 0.5726
# Epoch 00015: val_loss did not improve from 1.33933
# 448/448 [==============================] - 35s 78ms/step - loss: 1.3706 - accuracy: 0.5726 - val_loss: 1.3496 - val_accuracy: 0.5702
# Epoch 16/60
# 448/448 [==============================] - ETA: 0s - loss: 1.3374 - accuracy: 0.5798
# Epoch 00016: val_loss improved from 1.33933 to 1.31943, saving model to ferNet.h5
# 448/448 [==============================] - 36s 81ms/step - loss: 1.3374 - accuracy: 0.5798 - val_loss: 1.3194 - val_accuracy: 0.5876
# Epoch 17/60
# 448/448 [==============================] - ETA: 0s - loss: 1.3099 - accuracy: 0.5874
# Epoch 00017: val_loss improved from 1.31943 to 1.27540, saving model to ferNet.h5
# 448/448 [==============================] - 36s 80ms/step - loss: 1.3099 - accuracy: 0.5874 - val_loss: 1.2754 - val_accuracy: 0.6028
# Epoch 18/60
# 448/448 [==============================] - ETA: 0s - loss: 1.2795 - accuracy: 0.5980
# Epoch 00018: val_loss did not improve from 1.27540
# 448/448 [==============================] - 35s 78ms/step - loss: 1.2795 - accuracy: 0.5980 - val_loss: 1.2755 - val_accuracy: 0.6000
# Epoch 19/60
# 448/448 [==============================] - ETA: 0s - loss: 1.2651 - accuracy: 0.5996
# Epoch 00019: val_loss improved from 1.27540 to 1.22010, saving model to ferNet.h5
# 448/448 [==============================] - 36s 80ms/step - loss: 1.2651 - accuracy: 0.5996 - val_loss: 1.2201 - val_accuracy: 0.6140
# Epoch 20/60
# 448/448 [==============================] - ETA: 0s - loss: 1.2457 - accuracy: 0.6065
# Epoch 00020: val_loss did not improve from 1.22010
# 448/448 [==============================] - 36s 80ms/step - loss: 1.2457 - accuracy: 0.6065 - val_loss: 1.2603 - val_accuracy: 0.5964
# Epoch 21/60
# 448/448 [==============================] - ETA: 0s - loss: 1.2274 - accuracy: 0.6101
# Epoch 00021: val_loss did not improve from 1.22010
# 448/448 [==============================] - 37s 83ms/step - loss: 1.2274 - accuracy: 0.6101 - val_loss: 1.2340 - val_accuracy: 0.6085
# Epoch 22/60
# 448/448 [==============================] - ETA: 0s - loss: 1.2143 - accuracy: 0.6161
# Epoch 00022: val_loss improved from 1.22010 to 1.18730, saving model to ferNet.h5
# 448/448 [==============================] - 34s 77ms/step - loss: 1.2143 - accuracy: 0.6161 - val_loss: 1.1873 - val_accuracy: 0.6215
# Epoch 23/60
# 448/448 [==============================] - ETA: 0s - loss: 1.1994 - accuracy: 0.6215
# Epoch 00023: val_loss did not improve from 1.18730
# 448/448 [==============================] - 34s 77ms/step - loss: 1.1994 - accuracy: 0.6215 - val_loss: 1.2051 - val_accuracy: 0.6210
# Epoch 24/60
# 448/448 [==============================] - ETA: 0s - loss: 1.1841 - accuracy: 0.6247
# Epoch 00024: val_loss did not improve from 1.18730
# 448/448 [==============================] - 34s 75ms/step - loss: 1.1841 - accuracy: 0.6247 - val_loss: 1.2297 - val_accuracy: 0.6136
# Epoch 25/60
# 448/448 [==============================] - ETA: 0s - loss: 1.1788 - accuracy: 0.6280
# Epoch 00025: val_loss improved from 1.18730 to 1.18007, saving model to ferNet.h5
# 448/448 [==============================] - 35s 79ms/step - loss: 1.1788 - accuracy: 0.6280 - val_loss: 1.1801 - val_accuracy: 0.6307
# Epoch 26/60
# 448/448 [==============================] - ETA: 0s - loss: 1.1617 - accuracy: 0.6300
# Epoch 00026: val_loss did not improve from 1.18007
# 448/448 [==============================] - 35s 78ms/step - loss: 1.1617 - accuracy: 0.6300 - val_loss: 1.1976 - val_accuracy: 0.6277
# Epoch 27/60
# 448/448 [==============================] - ETA: 0s - loss: 1.1509 - accuracy: 0.6352
# Epoch 00027: val_loss did not improve from 1.18007
# 448/448 [==============================] - 36s 80ms/step - loss: 1.1509 - accuracy: 0.6352 - val_loss: 1.1849 - val_accuracy: 0.6295
# Epoch 28/60
# 448/448 [==============================] - ETA: 0s - loss: 1.1389 - accuracy: 0.6411
# Epoch 00028: val_loss did not improve from 1.18007
# 448/448 [==============================] - 36s 81ms/step - loss: 1.1389 - accuracy: 0.6411 - val_loss: 1.1916 - val_accuracy: 0.6230
# Epoch 29/60
# 448/448 [==============================] - ETA: 0s - loss: 1.1305 - accuracy: 0.6459
# Epoch 00029: val_loss improved from 1.18007 to 1.13757, saving model to ferNet.h5
# 448/448 [==============================] - 35s 78ms/step - loss: 1.1305 - accuracy: 0.6459 - val_loss: 1.1376 - val_accuracy: 0.6449
# Epoch 30/60
# 448/448 [==============================] - ETA: 0s - loss: 1.1186 - accuracy: 0.6489
# Epoch 00030: val_loss improved from 1.13757 to 1.13055, saving model to ferNet.h5
# 448/448 [==============================] - 39s 86ms/step - loss: 1.1186 - accuracy: 0.6489 - val_loss: 1.1306 - val_accuracy: 0.6419
# Epoch 31/60
# 448/448 [==============================] - ETA: 0s - loss: 1.1152 - accuracy: 0.6480
# Epoch 00031: val_loss did not improve from 1.13055
# 448/448 [==============================] - 35s 77ms/step - loss: 1.1152 - accuracy: 0.6480 - val_loss: 1.1633 - val_accuracy: 0.6417
# Epoch 32/60
# 448/448 [==============================] - ETA: 0s - loss: 1.1003 - accuracy: 0.6564
# Epoch 00032: val_loss did not improve from 1.13055
# 448/448 [==============================] - 36s 80ms/step - loss: 1.1003 - accuracy: 0.6564 - val_loss: 1.1344 - val_accuracy: 0.6504
# Epoch 33/60
# 448/448 [==============================] - ETA: 0s - loss: 1.0914 - accuracy: 0.6626
# Epoch 00033: val_loss did not improve from 1.13055
# 448/448 [==============================] - 34s 75ms/step - loss: 1.0914 - accuracy: 0.6626 - val_loss: 1.1583 - val_accuracy: 0.6367
# Epoch 34/60
# 448/448 [==============================] - ETA: 0s - loss: 1.0911 - accuracy: 0.6614
# Epoch 00034: val_loss did not improve from 1.13055
# 448/448 [==============================] - 34s 76ms/step - loss: 1.0911 - accuracy: 0.6614 - val_loss: 1.1758 - val_accuracy: 0.6410
# Epoch 35/60
# 448/448 [==============================] - ETA: 0s - loss: 1.0721 - accuracy: 0.6702
# Epoch 00035: val_loss did not improve from 1.13055
# 448/448 [==============================] - 33s 73ms/step - loss: 1.0721 - accuracy: 0.6702 - val_loss: 1.1620 - val_accuracy: 0.6496
# Epoch 36/60
# 448/448 [==============================] - ETA: 0s - loss: 1.0691 - accuracy: 0.6694
# Epoch 00036: val_loss did not improve from 1.13055
#
# Epoch 00036: ReduceLROnPlateau reducing learning rate to 1.9999999494757503e-05.
# 448/448 [==============================] - 34s 76ms/step - loss: 1.0691 - accuracy: 0.6694 - val_loss: 1.1336 - val_accuracy: 0.6448
# Epoch 37/60
# 448/448 [==============================] - ETA: 0s - loss: 0.9956 - accuracy: 0.6987
# Epoch 00037: val_loss improved from 1.13055 to 1.09629, saving model to ferNet.h5
# 448/448 [==============================] - 33s 73ms/step - loss: 0.9956 - accuracy: 0.6987 - val_loss: 1.0963 - val_accuracy: 0.6666
# Epoch 38/60
# 448/448 [==============================] - ETA: 0s - loss: 0.9639 - accuracy: 0.7087
# Epoch 00038: val_loss improved from 1.09629 to 1.08299, saving model to ferNet.h5
# 448/448 [==============================] - 36s 80ms/step - loss: 0.9639 - accuracy: 0.7087 - val_loss: 1.0830 - val_accuracy: 0.6706
# Epoch 39/60
# 448/448 [==============================] - ETA: 0s - loss: 0.9440 - accuracy: 0.7170
# Epoch 00039: val_loss did not improve from 1.08299
# 448/448 [==============================] - 33s 74ms/step - loss: 0.9440 - accuracy: 0.7170 - val_loss: 1.0898 - val_accuracy: 0.6708
# Epoch 40/60
# 448/448 [==============================] - ETA: 0s - loss: 0.9288 - accuracy: 0.7205
# Epoch 00040: val_loss did not improve from 1.08299
# 448/448 [==============================] - 35s 79ms/step - loss: 0.9288 - accuracy: 0.7205 - val_loss: 1.0899 - val_accuracy: 0.6660
# Epoch 41/60
# 448/448 [==============================] - ETA: 0s - loss: 0.9179 - accuracy: 0.7210
# Epoch 00041: val_loss did not improve from 1.08299
# 448/448 [==============================] - 76s 169ms/step - loss: 0.9179 - accuracy: 0.7210 - val_loss: 1.0853 - val_accuracy: 0.6706
# Epoch 42/60
# 448/448 [==============================] - ETA: 0s - loss: 0.9087 - accuracy: 0.7233
# Epoch 00042: val_loss improved from 1.08299 to 1.07851, saving model to ferNet.h5
# 448/448 [==============================] - 35s 78ms/step - loss: 0.9087 - accuracy: 0.7233 - val_loss: 1.0785 - val_accuracy: 0.6709
# Epoch 43/60
# 448/448 [==============================] - ETA: 0s - loss: 0.8950 - accuracy: 0.7280
# Epoch 00043: val_loss improved from 1.07851 to 1.06749, saving model to ferNet.h5
# 448/448 [==============================] - 33s 73ms/step - loss: 0.8950 - accuracy: 0.7280 - val_loss: 1.0675 - val_accuracy: 0.6783
# Epoch 44/60
# 448/448 [==============================] - ETA: 0s - loss: 0.8936 - accuracy: 0.7279
# Epoch 00044: val_loss did not improve from 1.06749
# 448/448 [==============================] - 33s 73ms/step - loss: 0.8936 - accuracy: 0.7279 - val_loss: 1.0774 - val_accuracy: 0.6713
# Epoch 45/60
# 448/448 [==============================] - ETA: 0s - loss: 0.8857 - accuracy: 0.7313
# Epoch 00045: val_loss improved from 1.06749 to 1.06274, saving model to ferNet.h5
# 448/448 [==============================] - 35s 78ms/step - loss: 0.8857 - accuracy: 0.7313 - val_loss: 1.0627 - val_accuracy: 0.6729
# Epoch 46/60
# 448/448 [==============================] - ETA: 0s - loss: 0.8805 - accuracy: 0.7326
# Epoch 00046: val_loss improved from 1.06274 to 1.05961, saving model to ferNet.h5
# 448/448 [==============================] - 34s 75ms/step - loss: 0.8805 - accuracy: 0.7326 - val_loss: 1.0596 - val_accuracy: 0.6763
# Epoch 47/60
# 448/448 [==============================] - ETA: 0s - loss: 0.8655 - accuracy: 0.7351
# Epoch 00047: val_loss improved from 1.05961 to 1.04897, saving model to ferNet.h5
# 448/448 [==============================] - 34s 75ms/step - loss: 0.8655 - accuracy: 0.7351 - val_loss: 1.0490 - val_accuracy: 0.6787
# Epoch 48/60
# 448/448 [==============================] - ETA: 0s - loss: 0.8557 - accuracy: 0.7415
# Epoch 00048: val_loss did not improve from 1.04897
# 448/448 [==============================] - 33s 73ms/step - loss: 0.8557 - accuracy: 0.7415 - val_loss: 1.0647 - val_accuracy: 0.6749
# Epoch 49/60
# 448/448 [==============================] - ETA: 0s - loss: 0.8506 - accuracy: 0.7394
# Epoch 00049: val_loss did not improve from 1.04897
# 448/448 [==============================] - 35s 78ms/step - loss: 0.8506 - accuracy: 0.7394 - val_loss: 1.0574 - val_accuracy: 0.6763
# Epoch 50/60
# 448/448 [==============================] - ETA: 0s - loss: 0.8466 - accuracy: 0.7423
# Epoch 00050: val_loss did not improve from 1.04897
# 448/448 [==============================] - 32s 71ms/step - loss: 0.8466 - accuracy: 0.7423 - val_loss: 1.0666 - val_accuracy: 0.6801
# Epoch 51/60
# 448/448 [==============================] - ETA: 0s - loss: 0.8324 - accuracy: 0.7475
# Epoch 00051: val_loss did not improve from 1.04897
# 448/448 [==============================] - 32s 72ms/step - loss: 0.8324 - accuracy: 0.7475 - val_loss: 1.0614 - val_accuracy: 0.6742
# Epoch 52/60
# 448/448 [==============================] - ETA: 0s - loss: 0.8290 - accuracy: 0.7497
# Epoch 00052: val_loss did not improve from 1.04897
# 448/448 [==============================] - 32s 71ms/step - loss: 0.8290 - accuracy: 0.7497 - val_loss: 1.0512 - val_accuracy: 0.6776
# Epoch 53/60
# 448/448 [==============================] - ETA: 0s - loss: 0.8254 - accuracy: 0.7506
# Epoch 00053: val_loss did not improve from 1.04897
#
# Epoch 00053: ReduceLROnPlateau reducing learning rate to 3.999999898951501e-06.
# 448/448 [==============================] - 37s 82ms/step - loss: 0.8254 - accuracy: 0.7506 - val_loss: 1.0559 - val_accuracy: 0.6793
# Epoch 54/60
# 448/448 [==============================] - ETA: 0s - loss: 0.8094 - accuracy: 0.7555
# Epoch 00054: val_loss improved from 1.04897 to 1.04593, saving model to ferNet.h5
# 448/448 [==============================] - 33s 74ms/step - loss: 0.8094 - accuracy: 0.7555 - val_loss: 1.0459 - val_accuracy: 0.6851
# Epoch 55/60
# 448/448 [==============================] - ETA: 0s - loss: 0.8017 - accuracy: 0.7595
# Epoch 00055: val_loss did not improve from 1.04593
# 448/448 [==============================] - 33s 73ms/step - loss: 0.8017 - accuracy: 0.7595 - val_loss: 1.0524 - val_accuracy: 0.6829
# Epoch 56/60
# 448/448 [==============================] - ETA: 0s - loss: 0.7963 - accuracy: 0.7625
# Epoch 00056: val_loss did not improve from 1.04593
# 448/448 [==============================] - 32s 72ms/step - loss: 0.7963 - accuracy: 0.7625 - val_loss: 1.0464 - val_accuracy: 0.6839
# Epoch 57/60
# 448/448 [==============================] - ETA: 0s - loss: 0.8006 - accuracy: 0.7576
# Epoch 00057: val_loss improved from 1.04593 to 1.04420, saving model to ferNet.h5
# 448/448 [==============================] - 37s 83ms/step - loss: 0.8006 - accuracy: 0.7576 - val_loss: 1.0442 - val_accuracy: 0.6830
# Epoch 58/60
# 448/448 [==============================] - ETA: 0s - loss: 0.7953 - accuracy: 0.7610
# Epoch 00058: val_loss did not improve from 1.04420
# 448/448 [==============================] - 33s 73ms/step - loss: 0.7953 - accuracy: 0.7610 - val_loss: 1.0483 - val_accuracy: 0.6826
# Epoch 59/60
# 448/448 [==============================] - ETA: 0s - loss: 0.7926 - accuracy: 0.7619
# Epoch 00059: val_loss did not improve from 1.04420
# 448/448 [==============================] - 32s 72ms/step - loss: 0.7926 - accuracy: 0.7619 - val_loss: 1.0472 - val_accuracy: 0.6861
# Epoch 60/60
# 448/448 [==============================] - ETA: 0s - loss: 0.7890 - accuracy: 0.7611
# Epoch 00060: val_loss did not improve from 1.04420
# 448/448 [==============================] - 33s 74ms/step - loss: 0.7890 - accuracy: 0.7611 - val_loss: 1.0476 - val_accuracy: 0.6853

# %% [markdown]
# ## Loss and Accuracy plot

# %%
# Plotting the loss and accuracy plots for the training and testing dataset

plt.figure(figsize=(14,5))  # Initializing a figure for the plot
plt.subplot(1,2,2)      # Creating a subplot for second graph
plt.plot(hist.history['accuracy'])  # Plotting the values
plt.plot(hist.history['val_accuracy']) # Plotting the values
plt.title('Model Accuracy')  # Giving the subplot a title
plt.xlabel('Epochs')        # Providing x-label for the subplot
plt.ylabel('Accuracy')      # Providing y-label for the subplot
plt.legend(['train', 'test'], loc='upper left')  # Creating a legend on the upper left corner

plt.subplot(1,2,1)  # Creating a subplot for first graph
plt.plot(hist.history['loss'])  # Plotting the values
plt.plot(hist.history['val_loss'])  # Plotting the values
plt.title('model Loss')  # Giving the subplot a title
plt.xlabel('Epochs')  # Providing x-label for the subplot
plt.ylabel('Loss')    # Providing y-label for the subplot
plt.legend(['train', 'test'], loc='upper left')  # Creating a legend on the upper left corner
plt.show()  # Displaying the plot to the output console

# %% [markdown]
# ### Model evaluation

# %%
# Evaluating the model for training loss,training accuracy, testing loss and testing accuracy using evaluate function
train_loss, train_accu = fernet.evaluate(training_set)
test_loss, test_accu = fernet.evaluate(test_set)

# Printing the accuracy in the percentage format
print("final train accuracy = {:.2f} , validation accuracy = {:.2f}".format(train_accu*100, test_accu*100))
# Out:
# 449/449 [==============================] - 25s 55ms/step - loss: 0.6637 - accuracy: 0.8205
# 113/113 [==============================] - 4s 36ms/step - loss: 1.0468 - accuracy: 0.6856
# final train accuracy = 82.05 , validation accuracy = 68.56

# %%
# Saving the weights to a file
fernet.save_weights('./Model/Model_bestweight.h5')

# %% [markdown]
# ### Confusion Matrix and Classification on training set

# %%
# Generates output predictions for the training set.

y_pred = fernet.predict(training_set)
y_pred = np.argmax(y_pred, axis=1)
class_labels = test_set.class_indices
class_labels = {v:k for k,v in class_labels.items()}

# Creating a classification report and confusion matrix for the given training data
from sklearn.metrics import classification_report, confusion_matrix
cm_train = confusion_matrix(training_set.classes, y_pred)
print('Confusion Matrix')
print(cm_train)
print('Classification Report')
target_names = list(class_labels.values())
print(classification_report(training_set.classes, y_pred, target_names=target_names))

# Creating a figure for the plot to show the report
plt.figure(figsize=(8,8))
plt.imshow(cm_train, interpolation='nearest')
plt.colorbar()
tick_mark = np.arange(len(target_names))
_ = plt.xticks(tick_mark, target_names, rotation=90)
_ = plt.yticks(tick_mark, target_names)
# Out:
# Confusion Matrix
# [[ 564   61  463 1048  726  671  462]
#  [  58   10   49  110   78   79   52]
#  [ 564   53  508 1069  800  645  458]
#  [ 957  101  844 1897 1410 1193  813]
#  [ 658   70  606 1263  950  878  540]
#  [ 686   59  580 1208  933  811  553]
#  [ 418   38  390  813  630  550  332]]
# Classification Report
#               precision    recall  f1-score   support
#
#        angry       0.14      0.14      0.14      3995
#      disgust       0.03      0.02      0.02       436
#         fear       0.15      0.12      0.13      4097
#        happy       0.26      0.26      0.26      7215
#      neutral       0.17      0.19      0.18      4965
#          sad       0.17      0.17      0.17      4830
#     surprise       0.10      0.10      0.10      3171
#
#     accuracy                           0.18     28709
#    macro avg       0.15      0.14      0.14     28709
# weighted avg       0.18      0.18      0.18     28709

# %% [markdown]
# ### Confusion Matrix and Classification on test set

# %%
# Generates output predictions for the testing set.

y_pred = fernet.predict(test_set)
y_pred = np.argmax(y_pred, axis=1)
class_labels = test_set.class_indices
class_labels = {v:k for k,v in class_labels.items()}

# Creating a classification report and confusion matrix for the given testing data
cm_test = confusion_matrix(test_set.classes, y_pred)
print('Confusion Matrix')
print(cm_test)
print('Classification Report')
target_names = list(class_labels.values())
print(classification_report(test_set.classes, y_pred, target_names=target_names))

# Creating a figure for the plot to show the report
plt.figure(figsize=(8,8))
plt.imshow(cm_test, interpolation='nearest')
plt.colorbar()
tick_mark = np.arange(len(target_names))
_ = plt.xticks(tick_mark, target_names, rotation=90)
_ = plt.yticks(tick_mark, target_names)
# Out:
# Confusion Matrix
# [[134  13 116 224 200 167 104]
#  [ 12   0  22  25  14  26  12]
#  [147  10 136 244 198 160 129]
#  [233  20 219 444 343 308 207]
#  [186  13 135 281 265 206 147]
#  [179  12 122 338 258 206 132]
#  [113   8 114 200 155 144  97]]
# Classification Report
#               precision    recall  f1-score   support
#
#        angry       0.13      0.14      0.14       958
#      disgust       0.00      0.00      0.00       111
#         fear       0.16      0.13      0.14      1024
#        happy       0.25      0.25      0.25      1774
#      neutral       0.18      0.21      0.20      1233
#          sad       0.17      0.17      0.17      1247
#     surprise       0.12      0.12      0.12       831
#
#     accuracy                           0.18      7178
#    macro avg       0.15      0.15      0.15      7178
# weighted avg       0.18      0.18      0.18      7178
